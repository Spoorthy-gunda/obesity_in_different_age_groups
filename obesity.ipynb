# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 500)                                                                                                                                                                                                                           
pd.set_option('display.max_columns', 500)

data = pd.read_csv("./Nutrition__Physical.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
#  13  Data_Value_Footnote         5046 non-null   object
#  14  Low_Confidence_Limit        48346 non-null  float64
#  15  High_Confidence_Limit       48346 non-null  float64
#  16  Sample_Size                 48346 non-null  float64
#  17  Total                       1907 non-null   object
#  18  Age(years)                  11438 non-null  object
#  19  Education                   7628 non-null   object
#  20  Gender                      3814 non-null   object
#  21  Income                      13349 non-null  object
#  22  Race/Ethnicity              15256 non-null  object
#  23  GeoLocation                 52384 non-null  object
#  24  ClassID                     53392 non-null  object
#  25  TopicID                     53392 non-null  object
#  26  QuestionID                  53392 non-null  object
#  27  DataValueTypeID             53392 non-null  object
#  28  LocationID                  53392 non-null  int64
#  29  StratificationCategory1     53392 non-null  object
#  30  Stratification1             53392 non-null  object
#  31  StratificationCategoryId1   53392 non-null  object
#  32  StratificationID1           53392 non-null  object
# dtypes: float64(6), int64(3), object(24)
# memory usage: 13.4+ MB

# %%
data.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 3  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 4  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
#
#    Data_Value_Unit Data_Value_Type  Data_Value  Data_Value_Alt  \
# 0              NaN           Value        32.0            32.0
# 1              NaN           Value        32.3            32.3
# 2              NaN           Value        31.8            31.8
# 3              NaN           Value        33.6            33.6
# 4              NaN           Value        32.8            32.8
#
#   Data_Value_Footnote_Symbol Data_Value_Footnote  Low_Confidence_Limit  \
# 0                        NaN                 NaN                  30.5
# 1                        NaN                 NaN                  29.9
# 2                        NaN                 NaN                  30.0
# 3                        NaN                 NaN                  29.9
# 4                        NaN                 NaN                  30.2
#
#    High_Confidence_Limit   Sample_Size  Total Age(years)  \
# 0                    33.5       7304.0  Total        NaN
# 1                    34.7       2581.0    NaN        NaN
# 2                    33.6       4723.0    NaN        NaN
# 3                    37.6       1153.0    NaN        NaN
# 4                    35.6       2402.0    NaN        NaN
#
#                Education  Gender Income Race/Ethnicity  \
# 0                    NaN     NaN    NaN            NaN
# 1                    NaN    Male    NaN            NaN
# 2                    NaN  Female    NaN            NaN
# 3  Less than high school     NaN    NaN            NaN
# 4   High school graduate     NaN    NaN            NaN
#
#                                GeoLocation ClassID TopicID QuestionID  \
# 0  (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# 1  (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# 2  (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# 3  (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
# 4  (32.84057112200048, -86.63186076199969)     OWS    OWS1       Q036
#
#   DataValueTypeID  LocationID StratificationCategory1        Stratification1  \
# 0           VALUE           1                   Total                  Total
# 1           VALUE           1                  Gender                   Male
# 2           VALUE           1                  Gender                 Female
# 3           VALUE           1               Education  Less than high school
# 4           VALUE           1               Education   High school graduate
#
#   StratificationCategoryId1 StratificationID1
# 0                       OVR           OVERALL
# 1                       GEN              MALE
# 2                       GEN            FEMALE
# 3                       EDU             EDUHS
# 4                       EDU         EDUHSGRAD

# %%
data.tail()
# Out:
#        YearStart  YearEnd LocationAbbr    LocationDesc  \
# 53387       2016     2016           VI  Virgin Islands
# 53388       2016     2016           VI  Virgin Islands
# 53389       2016     2016           VI  Virgin Islands
# 53390       2016     2016           VI  Virgin Islands
# 53391       2016     2016           VI  Virgin Islands
#
#                                        Datasource              Class  \
# 53387  Behavioral Risk Factor Surveillance System  Physical Activity
# 53388  Behavioral Risk Factor Surveillance System  Physical Activity
# 53389  Behavioral Risk Factor Surveillance System  Physical Activity
# 53390  Behavioral Risk Factor Surveillance System  Physical Activity
# 53391  Behavioral Risk Factor Surveillance System  Physical Activity
#
#                               Topic  \
# 53387  Physical Activity - Behavior
# 53388  Physical Activity - Behavior
# 53389  Physical Activity - Behavior
# 53390  Physical Activity - Behavior
# 53391  Physical Activity - Behavior
#
#                                                 Question  Data_Value_Unit  \
# 53387  Percent of adults who engage in no leisure-tim...              NaN
# 53388  Percent of adults who engage in no leisure-tim...              NaN
# 53389  Percent of adults who engage in no leisure-tim...              NaN
# 53390  Percent of adults who engage in no leisure-tim...              NaN
# 53391  Percent of adults who engage in no leisure-tim...              NaN
#
#       Data_Value_Type  Data_Value  Data_Value_Alt Data_Value_Footnote_Symbol  \
# 53387           Value         NaN             NaN                          ~
# 53388           Value         NaN             NaN                          ~
# 53389           Value         NaN             NaN                          ~
# 53390           Value         NaN             NaN                          ~
# 53391           Value         NaN             NaN                          ~
#
#                                      Data_Value_Footnote  \
# 53387  Data not available because sample size is insu...
# 53388  Data not available because sample size is insu...
# 53389  Data not available because sample size is insu...
# 53390  Data not available because sample size is insu...
# 53391  Data not available because sample size is insu...
#
#        Low_Confidence_Limit  High_Confidence_Limit   Sample_Size Total  \
# 53387                   NaN                     NaN          NaN   NaN
# 53388                   NaN                     NaN          NaN   NaN
# 53389                   NaN                     NaN          NaN   NaN
# 53390                   NaN                     NaN          NaN   NaN
# 53391                   NaN                     NaN          NaN   NaN
#
#       Age(years) Education Gender Income                 Race/Ethnicity  \
# 53387        NaN       NaN    NaN    NaN                          Asian
# 53388        NaN       NaN    NaN    NaN      Hawaiian/Pacific Islander
# 53389        NaN       NaN    NaN    NaN  American Indian/Alaska Native
# 53390        NaN       NaN    NaN    NaN                2 or more races
# 53391        NaN       NaN    NaN    NaN                          Other
#
#                    GeoLocation ClassID TopicID QuestionID DataValueTypeID  \
# 53387  (18.335765, -64.896335)      PA     PA1       Q047           VALUE
# 53388  (18.335765, -64.896335)      PA     PA1       Q047           VALUE
# 53389  (18.335765, -64.896335)      PA     PA1       Q047           VALUE
# 53390  (18.335765, -64.896335)      PA     PA1       Q047           VALUE
# 53391  (18.335765, -64.896335)      PA     PA1       Q047           VALUE
#
#        LocationID StratificationCategory1                Stratification1  \
# 53387          78          Race/Ethnicity                          Asian
# 53388          78          Race/Ethnicity      Hawaiian/Pacific Islander
# 53389          78          Race/Ethnicity  American Indian/Alaska Native
# 53390          78          Race/Ethnicity                2 or more races
# 53391          78          Race/Ethnicity                          Other
#
#       StratificationCategoryId1 StratificationID1
# 53387                      RACE           RACEASN
# 53388                      RACE           RACEHPI
# 53389                      RACE           RACENAA
# 53390                      RACE         RACE2PLUS
# 53391                      RACE           RACEOTH

# %%
for col in data:    
    print(col, data[col].nunique())
# Out:
# YearStart 6
# YearEnd 6
# LocationAbbr 55
# LocationDesc 55
# Datasource 1
# Class 3
# Topic 3
# Question 9
# Data_Value_Unit 0
# Data_Value_Type 1
# Data_Value 669
# Data_Value_Alt 669
# Data_Value_Footnote_Symbol 1
# Data_Value_Footnote 2
# Low_Confidence_Limit 654
# High_Confidence_Limit  723
# Sample_Size 8123
# Total 1
# Age(years) 6
# Education 4
# Gender 2
# Income 7
# Race/Ethnicity 8
# GeoLocation 54
# ClassID 3
# TopicID 3
# QuestionID 9
# DataValueTypeID 1
# LocationID 55
# StratificationCategory1 6
# Stratification1 28
# StratificationCategoryId1 6
# StratificationID1 28

# %% [markdown]
# 1. LocationAbbr and LocationID can be deleted as we have locationDesc
# 2. ClassID, TopicID, QuestionID, StratificationCategoryId1,StratificationID1
# 3. Data value Unit has no values so we can ignore the column, similarly DataValueTypeID is the same for everything.
# 4. Data_value_Alt and the Data_value are the same, in the description it is mentioned that Data_value_Alt is the numerical representation of Data_value but both of them have float as the data type.
# 5. Datasource is the same for every data point so we can ignore that column.
# 6. GeoLocation has the lattitude and longitude values of the location, so we can ignore that column as it does not provide any other extra information about te location apart from locationID.

# %%
data =  data.drop(columns=['LocationAbbr', 'Datasource', 'Class', 'High_Confidence_Limit ', 'Low_Confidence_Limit', 'Topic', 'Data_Value_Unit', 'Data_Value', 'Data_Value_Type','GeoLocation', 'DataValueTypeID', 'StratificationCategory1', 'Stratification1'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationDesc                53392 non-null  object
#  3   Question                    53392 non-null  object
#  4   Data_Value_Alt              48346 non-null  float64
#  5   Data_Value_Footnote_Symbol  5046 non-null   object
#  6   Data_Value_Footnote         5046 non-null   object
#  7   Sample_Size                 48346 non-null  float64
#  8   Total                       1907 non-null   object
#  9   Age(years)                  11438 non-null  object
#  10  Education                   7628 non-null   object
#  11  Gender                      3814 non-null   object
#  12  Income                      13349 non-null  object
#  13  Race/Ethnicity              15256 non-null  object
#  14  ClassID                     53392 non-null  object
#  15  TopicID                     53392 non-null  object
#  16  QuestionID                  53392 non-null  object
#  17  LocationID                  53392 non-null  int64
#  18  StratificationCategoryId1   53392 non-null  object
#  19  StratificationID1           53392 non-null  object
# dtypes: float64(2), int64(3), object(15)
# memory usage: 8.1+ MB

# %% [markdown]
# #### Observation:
# Data_Value_Footnote_Symbol or the Data_value_Footnote is present when the Data_Value_Alt is not available in that row. 53392 is the total rows, foot note is present for 5046 rows and data values ae available for 48346(48346+5046 = 53392).

# %%
data1 = (data['Data_Value_Footnote'].isnull()|data['Data_Value_Footnote_Symbol'].isnull())
data = data[data1]
data = data.drop(columns = ['Data_Value_Footnote_Symbol', 'Data_Value_Footnote'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48346 entries, 0 to 53386
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  48346 non-null  int64
#  1   YearEnd                    48346 non-null  int64
#  2   LocationDesc               48346 non-null  object
#  3   Question                   48346 non-null  object
#  4   Data_Value_Alt             48346 non-null  float64
#  5   Sample_Size                48346 non-null  float64
#  6   Total                      1907 non-null   object
#  7   Age(years)                 11438 non-null  object
#  8   Education                  7628 non-null   object
#  9   Gender                     3814 non-null   object
#  10  Income                     13349 non-null  object
#  11  Race/Ethnicity             10210 non-null  object
#  12  ClassID                    48346 non-null  object
#  13  TopicID                    48346 non-null  object
#  14  QuestionID                 48346 non-null  object
#  15  LocationID                 48346 non-null  int64
#  16  StratificationCategoryId1  48346 non-null  object
#  17  StratificationID1          48346 non-null  object
# dtypes: float64(2), int64(3), object(13)
# memory usage: 7.0+ MB

# %%
for col in data:    
    print(col, data[col].nunique())
# Out:
# YearStart 6
# YearEnd 6
# LocationDesc 55
# Question 9
# Data_Value_Alt 669
# Sample_Size 8123
# Total 1
# Age(years) 6
# Education 4
# Gender 2
# Income 7
# Race/Ethnicity 8
# ClassID 3
# TopicID 3
# QuestionID 9
# LocationID 55
# StratificationCategoryId1 6
# StratificationID1 28

# %%
data = data.astype({'Gender':'category', 'ClassID':'category', 'TopicID': 'category', 'QuestionID': 'category', 'LocationID':'category', 'StratificationCategoryId1':'category', 'StratificationID1': 'category', 'Gender': 'category', 'Race/Ethnicity': 'category', 'Education': 'category'})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48346 entries, 0 to 53386
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  48346 non-null  int64
#  1   YearEnd                    48346 non-null  int64
#  2   LocationDesc               48346 non-null  object
#  3   Question                   48346 non-null  object
#  4   Data_Value_Alt             48346 non-null  float64
#  5   Sample_Size                48346 non-null  float64
#  6   Total                      1907 non-null   object
#  7   Age(years)                 11438 non-null  object
#  8   Education                  7628 non-null   category
#  9   Gender                     3814 non-null   category
#  10  Income                     13349 non-null  object
#  11  Race/Ethnicity             10210 non-null  category
#  12  ClassID                    48346 non-null  category
#  13  TopicID                    48346 non-null  category
#  14  QuestionID                 48346 non-null  category
#  15  LocationID                 48346 non-null  category
#  16  StratificationCategoryId1  48346 non-null  category
#  17  StratificationID1          48346 non-null  category
# dtypes: category(9), float64(2), int64(2), object(5)
# memory usage: 4.1+ MB

# %%
data.head(20)
# Out:
#     YearStart  YearEnd LocationDesc  \
# 0        2011     2011      Alabama
# 1        2011     2011      Alabama
# 2        2011     2011      Alabama
# 3        2011     2011      Alabama
# 4        2011     2011      Alabama
# 5        2011     2011      Alabama
# 6        2011     2011      Alabama
# 7        2011     2011      Alabama
# 8        2011     2011      Alabama
# 9        2011     2011      Alabama
# 10       2011     2011      Alabama
# 11       2011     2011      Alabama
# 12       2011     2011      Alabama
# 13       2011     2011      Alabama
# 14       2011     2011      Alabama
# 15       2011     2011      Alabama
# 16       2011     2011      Alabama
# 17       2011     2011      Alabama
# 18       2011     2011      Alabama
# 19       2011     2011      Alabama
#
#                                              Question  Data_Value_Alt  \
# 0   Percent of adults aged 18 years and older who ...            32.0
# 1   Percent of adults aged 18 years and older who ...            32.3
# 2   Percent of adults aged 18 years and older who ...            31.8
# 3   Percent of adults aged 18 years and older who ...            33.6
# 4   Percent of adults aged 18 years and older who ...            32.8
# 5   Percent of adults aged 18 years and older who ...            33.8
# 6   Percent of adults aged 18 years and older who ...            26.4
# 7   Percent of adults aged 18 years and older who ...            16.3
# 8   Percent of adults aged 18 years and older who ...            35.2
# 9   Percent of adults aged 18 years and older who ...            35.5
# 10  Percent of adults aged 18 years and older who ...            38.0
# 11  Percent of adults aged 18 years and older who ...            36.4
# 12  Percent of adults aged 18 years and older who ...            27.1
# 13  Percent of adults aged 18 years and older who ...            38.5
# 14  Percent of adults aged 18 years and older who ...            34.8
# 15  Percent of adults aged 18 years and older who ...            35.8
# 16  Percent of adults aged 18 years and older who ...            32.3
# 17  Percent of adults aged 18 years and older who ...            34.1
# 18  Percent of adults aged 18 years and older who ...            28.8
# 19  Percent of adults aged 18 years and older who ...            23.8
#
#     Sample_Size  Total   Age(years)                         Education  Gender  \
# 0        7304.0  Total          NaN                               NaN     NaN
# 1        2581.0    NaN          NaN                               NaN    Male
# 2        4723.0    NaN          NaN                               NaN  Female
# 3        1153.0    NaN          NaN             Less than high school     NaN
# 4        2402.0    NaN          NaN              High school graduate     NaN
# 5        1925.0    NaN          NaN  Some college or technical school     NaN
# 6        1812.0    NaN          NaN                  College graduate     NaN
# 7         356.0    NaN      18 - 24                               NaN     NaN
# 8         598.0    NaN      25 - 34                               NaN     NaN
# 9         865.0    NaN      35 - 44                               NaN     NaN
# 10       1288.0    NaN      45 - 54                               NaN     NaN
# 11       1676.0    NaN      55 - 64                               NaN     NaN
# 12       2521.0    NaN  65 or older                               NaN     NaN
# 13       1112.0    NaN          NaN                               NaN     NaN
# 14       1367.0    NaN          NaN                               NaN     NaN
# 15        757.0    NaN          NaN                               NaN     NaN
# 16        861.0    NaN          NaN                               NaN     NaN
# 17        785.0    NaN          NaN                               NaN     NaN
# 18       1125.0    NaN          NaN                               NaN     NaN
# 19       1297.0    NaN          NaN                               NaN     NaN
#
#                 Income Race/Ethnicity ClassID TopicID QuestionID LocationID  \
# 0                  NaN            NaN     OWS    OWS1       Q036          1
# 1                  NaN            NaN     OWS    OWS1       Q036          1
# 2                  NaN            NaN     OWS    OWS1       Q036          1
# 3                  NaN            NaN     OWS    OWS1       Q036          1
# 4                  NaN            NaN     OWS    OWS1       Q036          1
# 5                  NaN            NaN     OWS    OWS1       Q036          1
# 6                  NaN            NaN     OWS    OWS1       Q036          1
# 7                  NaN            NaN     OWS    OWS1       Q036          1
# 8                  NaN            NaN     OWS    OWS1       Q036          1
# 9                  NaN            NaN     OWS    OWS1       Q036          1
# 10                 NaN            NaN     OWS    OWS1       Q036          1
# 11                 NaN            NaN     OWS    OWS1       Q036          1
# 12                 NaN            NaN     OWS    OWS1       Q036          1
# 13   Less than $15,000            NaN     OWS    OWS1       Q036          1
# 14   $15,000 - $24,999            NaN     OWS    OWS1       Q036          1
# 15   $25,000 - $34,999            NaN     OWS    OWS1       Q036          1
# 16   $35,000 - $49,999            NaN     OWS    OWS1       Q036          1
# 17   $50,000 - $74,999            NaN     OWS    OWS1       Q036          1
# 18  $75,000 or greater            NaN     OWS    OWS1       Q036          1
# 19   Data not reported            NaN     OWS    OWS1       Q036          1
#
#    StratificationCategoryId1 StratificationID1
# 0                        OVR           OVERALL
# 1                        GEN              MALE
# 2                        GEN            FEMALE
# 3                        EDU             EDUHS
# 4                        EDU         EDUHSGRAD
# 5                        EDU          EDUCOTEC
# 6                        EDU         EDUCOGRAD
# 7                      AGEYR         AGEYR1824
# 8                      AGEYR         AGEYR2534
# 9                      AGEYR         AGEYR3544
# 10                     AGEYR         AGEYR4554
# 11                     AGEYR         AGEYR5564
# 12                     AGEYR       AGEYR65PLUS
# 13                       INC         INCLESS15
# 14                       INC           INC1525
# 15                       INC           INC2535
# 16                       INC           INC3550
# 17                       INC           INC5075
# 18                       INC         INC75PLUS
# 19                       INC             INCNR

# %%
data.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Alt   Sample_Size
# count  48346.000000  48346.000000    48346.000000   48346.00000
# mean    2013.271646   2013.271646       31.156681    3889.19286
# std        1.694433      1.694433       10.247033   19829.42129
# min     2011.000000   2011.000000        0.900000      50.00000
# 25%     2012.000000   2012.000000       24.100000     566.00000
# 50%     2013.000000   2013.000000       30.700000    1209.00000
# 75%     2015.000000   2015.000000       37.000000    2519.00000
# max     2016.000000   2016.000000       77.600000  476876.00000

# %% [markdown]
# #### Observation:
# There are 6 stratificationCategoryId's and they correspond to Age, Education, Gender, Race/Ethnicity, Income, Total. Only the value corresponding to the StratificationCategory is present. So we can divide the data into 6 different sets, and perform individual analysis.

# %%
data_Age = data['Age(years)'].notnull()
dataAge= data[data_Age]
dataAge = dataAge.drop(columns = ['Total', 'Education', 'Gender', 'Income', 'Race/Ethnicity'])
dataAge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11438 entries, 7 to 53376
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  11438 non-null  int64
#  1   YearEnd                    11438 non-null  int64
#  2   LocationDesc               11438 non-null  object
#  3   Question                   11438 non-null  object
#  4   Data_Value_Alt             11438 non-null  float64
#  5   Sample_Size                11438 non-null  float64
#  6   Age(years)                 11438 non-null  object
#  7   ClassID                    11438 non-null  category
#  8   TopicID                    11438 non-null  category
#  9   QuestionID                 11438 non-null  category
#  10  LocationID                 11438 non-null  category
#  11  StratificationCategoryId1  11438 non-null  category
#  12  StratificationID1          11438 non-null  category
# dtypes: category(6), float64(2), int64(2), object(3)
# memory usage: 786.5+ KB

# %%
data['Question'].unique()
# Out:
# array(['Percent of adults aged 18 years and older who have obesity',
#        'Percent of adults aged 18 years and older who have an overweight classification',
#        'Percent of adults who report consuming fruit less than one time daily',
#        'Percent of adults who report consuming vegetables less than one time daily',
#        'Percent of adults who engage in muscle-strengthening activities on 2 or more days a week',
#        'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)',
#        'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic physical activity and engage in muscle-strengthening activities on 2 or more days a week',
#        'Percent of adults who achieve at least 300 minutes a week of moderate-intensity aerobic physical activity or 150 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)',
#        'Percent of adults who engage in no leisure-time physical activity'],
#       dtype=object)

# %%
Questions = dataAge.get(['Question','QuestionID'])
Questions.drop_duplicates()
# Out:
#                                               Question QuestionID
# 7    Percent of adults aged 18 years and older who ...       Q036
# 35   Percent of adults aged 18 years and older who ...       Q037
# 57   Percent of adults who report consuming fruit l...       Q018
# 91   Percent of adults who report consuming vegetab...       Q019
# 120  Percent of adults who achieve at least 150 min...       Q043
# 125  Percent of adults who engage in muscle-strengt...       Q046
# 150  Percent of adults who achieve at least 150 min...       Q044
# 178  Percent of adults who achieve at least 300 min...       Q045
# 232  Percent of adults who engage in no leisure-tim...       Q047

# %% [markdown]
# Lets now check if the number of datapoints for each category is balanced or not.

# %%
print(dataAge.groupby(['QuestionID', 'Age(years)']).count()['Sample_Size'])
# Out:
# QuestionID  Age(years)
# Q018        18 - 24        157
#             25 - 34        157
#             35 - 44        158
#             45 - 54        158
#             55 - 64        157
#             65 or older    157
# Q019        18 - 24        158
#             25 - 34        158
#             35 - 44        158
#             45 - 54        158
#             55 - 64        158
#             65 or older    158
# Q036        18 - 24        320
#             25 - 34        320
#             35 - 44        320
#             45 - 54        320
#             55 - 64        320
#             65 or older    320
# Q037        18 - 24        320
#             25 - 34        320
#             35 - 44        320
#             45 - 54        320
#             55 - 64        320
#             65 or older    320
# Q043        18 - 24        158
#             25 - 34        158
#             35 - 44        158
#             45 - 54        158
#             55 - 64        158
#             65 or older    158
# Q044        18 - 24        158
#             25 - 34        158
#             35 - 44        158
#             45 - 54        158
#             55 - 64        158
#             65 or older    158
# Q045        18 - 24        158
#             25 - 34        158
#             35 - 44        158
#             45 - 54        158
#             55 - 64        158
#             65 or older    158
# Q046        18 - 24        158
#             25 - 34        158
#             35 - 44        158
#             45 - 54        158
#             55 - 64        158
#             65 or older    158
# Q047        18 - 24        319
#             25 - 34        319
#             35 - 44        319
#             45 - 54        319
#             55 - 64        319
#             65 or older    319
# Name: Sample_Size, dtype: int64

# %%
dataAgeQ1 = dataAge.query('Question == "Percent of adults aged 18 years and older who have obesity"')
sns.catplot(x="Age(years)", y="Data_Value_Alt", data=dataAgeQ1, aspect =2.5)

# %%
dataAgeQ2 = dataAge.query('Question == "Percent of adults aged 18 years and older who have an overweight classification"')
print(dataAgeQ2.groupby('Age(years)').count()['Sample_Size'])
sns.catplot(x="Age(years)", y="Data_Value_Alt", data=dataAgeQ2)
# Out:
# Age(years)
# 18 - 24        320
# 25 - 34        320
# 35 - 44        320
# 45 - 54        320
# 55 - 64        320
# 65 or older    320
# Name: Sample_Size, dtype: int64

# %%
sns.catplot(x="QuestionID", y="Data_Value_Alt", data=dataAge, aspect =2.5, hue = 'Age(years)', kind ='bar')

# %% [markdown]
# 1. Q036, Q037 corresponds to the percent of adults who have obesity and overweight respectively. It is clear that the percent of adults aged between 18-24 who are obese/overweight is less when compared to the other aged groups.
# 2. The percent of adults who are overweight is increasing with the age, but the percent of adults who are obese is more for the age group 45-54.
# 3. Overall more percent of adults aged between 18-24 eat at least one fruit/vegetable (Q018 and Q019) and get more excercise(Q044, Q045, Q046) when compared to other aged groups and percent of adults who engege in no leisure time physical activity is less in the aged group 18-24.

# %%
data_Inc = data['Income'].notnull()
dataInc= data[data_Inc]
dataInc = dataInc.drop(columns = ['Total', 'Age(years)', 'Education', 'Gender', 'Race/Ethnicity'])
dataInc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13349 entries, 13 to 53383
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  13349 non-null  int64
#  1   YearEnd                    13349 non-null  int64
#  2   LocationDesc               13349 non-null  object
#  3   Question                   13349 non-null  object
#  4   Data_Value_Alt             13349 non-null  float64
#  5   Sample_Size                13349 non-null  float64
#  6   Income                     13349 non-null  object
#  7   ClassID                    13349 non-null  category
#  8   TopicID                    13349 non-null  category
#  9   QuestionID                 13349 non-null  category
#  10  LocationID                 13349 non-null  category
#  11  StratificationCategoryId1  13349 non-null  category
#  12  StratificationID1          13349 non-null  category
# dtypes: category(6), float64(2), int64(2), object(3)
# memory usage: 917.1+ KB

# %%
print(dataInc.groupby(['QuestionID', 'Income']).count()['Sample_Size'])
# Out:
# QuestionID  Income
# Q018        $15,000 - $24,999     158
#             $25,000 - $34,999     158
#             $35,000 - $49,999     158
#             $50,000 - $74,999     158
#             $75,000 or greater    158
#             Data not reported     158
#             Less than $15,000     158
# Q019        $15,000 - $24,999     158
#             $25,000 - $34,999     158
#             $35,000 - $49,999     158
#             $50,000 - $74,999     158
#             $75,000 or greater    158
#             Data not reported     158
#             Less than $15,000     158
# Q036        $15,000 - $24,999     320
#             $25,000 - $34,999     320
#             $35,000 - $49,999     320
#             $50,000 - $74,999     320
#             $75,000 or greater    320
#             Data not reported     320
#             Less than $15,000     320
# Q037        $15,000 - $24,999     320
#             $25,000 - $34,999     320
#             $35,000 - $49,999     320
#             $50,000 - $74,999     320
#             $75,000 or greater    320
#             Data not reported     320
#             Less than $15,000     320
# Q043        $15,000 - $24,999     158
#             $25,000 - $34,999     158
#             $35,000 - $49,999     158
#             $50,000 - $74,999     158
#             $75,000 or greater    158
#             Data not reported     158
#             Less than $15,000     158
# Q044        $15,000 - $24,999     158
#             $25,000 - $34,999     158
#             $35,000 - $49,999     158
#             $50,000 - $74,999     158
#             $75,000 or greater    158
#             Data not reported     158
#             Less than $15,000     158
# Q045        $15,000 - $24,999     158
#             $25,000 - $34,999     158
#             $35,000 - $49,999     158
#             $50,000 - $74,999     158
#             $75,000 or greater    158
#             Data not reported     158
#             Less than $15,000     158
# Q046        $15,000 - $24,999     158
#             $25,000 - $34,999     158
#             $35,000 - $49,999     158
#             $50,000 - $74,999     158
#             $75,000 or greater    158
#             Data not reported     158
#             Less than $15,000     158
# Q047        $15,000 - $24,999     319
#             $25,000 - $34,999     319
#             $35,000 - $49,999     319
#             $50,000 - $74,999     319
#             $75,000 or greater    319
#             Data not reported     319
#             Less than $15,000     319
# Name: Sample_Size, dtype: int64

# %%
sns.catplot(x="QuestionID", y="Data_Value_Alt", data=dataInc, aspect =2.5, hue = 'Income', kind ='bar')

# %%
data_Edu = data['Education'].notnull()
dataEdu= data[data_Edu]
dataEdu = dataEdu.drop(columns = ['Total', 'Age(years)', 'Gender', 'Income', 'Race/Ethnicity'])
dataEdu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7628 entries, 3 to 53370
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  7628 non-null   int64
#  1   YearEnd                    7628 non-null   int64
#  2   LocationDesc               7628 non-null   object
#  3   Question                   7628 non-null   object
#  4   Data_Value_Alt             7628 non-null   float64
#  5   Sample_Size                7628 non-null   float64
#  6   Education                  7628 non-null   category
#  7   ClassID                    7628 non-null   category
#  8   TopicID                    7628 non-null   category
#  9   QuestionID                 7628 non-null   category
#  10  LocationID                 7628 non-null   category
#  11  StratificationCategoryId1  7628 non-null   category
#  12  StratificationID1          7628 non-null   category
# dtypes: category(7), float64(2), int64(2), object(2)
# memory usage: 474.1+ KB

# %%
sns.catplot(x="QuestionID", y="Data_Value_Alt", data=dataEdu, aspect =2.5, hue = 'Education', kind ='bar')

# %% [markdown]
# 1. The percentage of adults who get good physical activity every week is more in the higher income range people when compared to the lower range income people(Q044, Q045, Q046).

# %%
data_Gen = data['Gender'].notnull()
dataGen= data[data_Gen]
dataGen = dataGen.drop(columns = ['Total', 'Age(years)', 'Education', 'Income', 'Race/Ethnicity'])
dataGen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3814 entries, 1 to 53366
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  3814 non-null   int64
#  1   YearEnd                    3814 non-null   int64
#  2   LocationDesc               3814 non-null   object
#  3   Question                   3814 non-null   object
#  4   Data_Value_Alt             3814 non-null   float64
#  5   Sample_Size                3814 non-null   float64
#  6   Gender                     3814 non-null   category
#  7   ClassID                    3814 non-null   category
#  8   TopicID                    3814 non-null   category
#  9   QuestionID                 3814 non-null   category
#  10  LocationID                 3814 non-null   category
#  11  StratificationCategoryId1  3814 non-null   category
#  12  StratificationID1          3814 non-null   category
# dtypes: category(7), float64(2), int64(2), object(2)
# memory usage: 239.4+ KB

# %%
print(dataGen.groupby(['Gender', 'QuestionID']).count()['Sample_Size'])
sns.catplot(x="QuestionID", y="Data_Value_Alt", data=dataGen, hue = 'Gender', kind='bar')
# Out:
# Gender  QuestionID
# Female  Q018          158
#         Q019          158
#         Q036          320
#         Q037          320
#         Q043          158
#         Q044          158
#         Q045          158
#         Q046          158
#         Q047          319
# Male    Q018          158
#         Q019          158
#         Q036          320
#         Q037          320
#         Q043          158
#         Q044          158
#         Q045          158
#         Q046          158
#         Q047          319
# Name: Sample_Size, dtype: int64

# %% [markdown]
# Percentage of males who eat at least one fruit/vegetable per day is greater than the percentage of females who eat at least one fruit/vegetable per day, similarly percentage of males who get excercise is greater than the percentage of females. But the percentage of males who are overweight is a lot more than the percentage of females who are overweight. The reason for this is probably becuase the physiological differences between male/female.

# %%
data_Race = data['Race/Ethnicity'].notnull()
dataRace= data[data_Race]
dataRace = dataRace.drop(columns = ['Total', 'Age(years)', 'Education', 'Gender', 'Income'])
dataRace.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10210 entries, 20 to 53386
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  10210 non-null  int64
#  1   YearEnd                    10210 non-null  int64
#  2   LocationDesc               10210 non-null  object
#  3   Question                   10210 non-null  object
#  4   Data_Value_Alt             10210 non-null  float64
#  5   Sample_Size                10210 non-null  float64
#  6   Race/Ethnicity             10210 non-null  category
#  7   ClassID                    10210 non-null  category
#  8   TopicID                    10210 non-null  category
#  9   QuestionID                 10210 non-null  category
#  10  LocationID                 10210 non-null  category
#  11  StratificationCategoryId1  10210 non-null  category
#  12  StratificationID1          10210 non-null  category
# dtypes: category(7), float64(2), int64(2), object(2)
# memory usage: 633.1+ KB

# %%
print(dataRace.groupby(['QuestionID', 'Race/Ethnicity']).count()['Sample_Size'])
# Out:
# QuestionID  Race/Ethnicity
# Q018        2 or more races                  141
#             American Indian/Alaska Native    104
#             Asian                             99
#             Hawaiian/Pacific Islander          9
#             Hispanic                         154
#             Non-Hispanic Black               124
#             Non-Hispanic White               157
#             Other                             54
# Q019        2 or more races                  141
#             American Indian/Alaska Native    101
#             Asian                             99
#             Hawaiian/Pacific Islander          9
#             Hispanic                         154
#             Non-Hispanic Black               124
#             Non-Hispanic White               157
#             Other                             51
# Q036        2 or more races                  290
#             American Indian/Alaska Native    213
#             Asian                            210
#             Hawaiian/Pacific Islander         22
#             Hispanic                         312
#             Non-Hispanic Black               255
#             Non-Hispanic White               316
#             Other                            109
# Q037        2 or more races                  290
#             American Indian/Alaska Native    213
#             Asian                            210
#             Hawaiian/Pacific Islander         22
#             Hispanic                         312
#             Non-Hispanic Black               255
#             Non-Hispanic White               316
#             Other                            109
# Q043        2 or more races                  141
#             American Indian/Alaska Native    100
#             Asian                             99
#             Hawaiian/Pacific Islander          9
#             Hispanic                         152
#             Non-Hispanic Black               123
#             Non-Hispanic White               157
#             Other                             53
# Q044        2 or more races                  140
#             American Indian/Alaska Native    100
#             Asian                             98
#             Hawaiian/Pacific Islander          9
#             Hispanic                         152
#             Non-Hispanic Black               123
#             Non-Hispanic White               157
#             Other                             52
# Q045        2 or more races                  141
#             American Indian/Alaska Native     99
#             Asian                             98
#             Hawaiian/Pacific Islander          9
#             Hispanic                         152
#             Non-Hispanic Black               123
#             Non-Hispanic White               157
#             Other                             52
# Q046        2 or more races                  141
#             American Indian/Alaska Native    104
#             Asian                            101
#             Hawaiian/Pacific Islander          9
#             Hispanic                         153
#             Non-Hispanic Black               123
#             Non-Hispanic White               157
#             Other                             55
# Q047        2 or more races                  292
#             American Indian/Alaska Native    215
#             Asian                            214
#             Hawaiian/Pacific Islander         21
#             Hispanic                         313
#             Non-Hispanic Black               254
#             Non-Hispanic White               316
#             Other                            114
# Name: Sample_Size, dtype: int64

# %%
sns.catplot(x="QuestionID", y="Data_Value_Alt", data=dataRace, aspect =3, hue = 'Race/Ethnicity', kind = 'bar')
